# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohit03singh/web_scraping_justwatch_project/blob/main/Individual_web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**NAME:Mohit**
# #**Cohort:Santiago**

# %% [markdown]
# #**Github:**https://github.com/Mohit03singh/web_scraping_justwatch_project

# %% [markdown]
# ## **Scraping TV  Show Data**

# %%
#Installing all necessary labraries
# !pip install bs4
# !pip install requests#Installing all necessary labraries
# !pip install bs4
# !pip install requests

# %%
#import all necessary labraries
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %%
# Specifying the URL from which tv show related data will be fetched
tv_url='https://www.justwatch.com/in/tv-shows?release_year_from=2000'
# Sending an HTTP GET request to the URL
page=requests.get(tv_url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(page.text,'html.parser')
# Printing the prettified HTML content
print(soup.prettify())

# %% [markdown]
# ## **Fetching Tv shows Url details**

# %%
# Write Your Code here
# URL of the main website
main_website_url = r'https://www.justwatch.com'

# Finding all <a> tags with the specified class for series links
series_links_html = soup.find_all('a', class_="title-list-grid__item--link")

# Using a list comprehension to create the list of complete series URLs
list_of_series_links = [main_website_url + link.get('href') for link in series_links_html]

# Printing the list of complete series URLs
print(list_of_series_links)
# Out:
# ['https://www.justwatch.com/in/tv-show/panchayat', 'https://www.justwatch.com/in/tv-show/game-of-thrones', 'https://www.justwatch.com/in/tv-show/mirzapur', 'https://www.justwatch.com/in/tv-show/shogun-2024', 'https://www.justwatch.com/in/tv-show/true-detective', 'https://www.justwatch.com/in/tv-show/avatar-the-last-airbender', 'https://www.justwatch.com/in/tv-show/one-day', 'https://www.justwatch.com/in/tv-show/aarya', 'https://www.justwatch.com/in/tv-show/solo-leveling-2024', 'https://www.justwatch.com/in/tv-show/sunflower-2021', 'https://www.justwatch.com/in/tv-show/halo', 'https://www.justwatch.com/in/tv-show/indian-police-force', 'https://www.justwatch.com/in/tv-show/death-and-other-details', 'https://www.justwatch.com/in/tv-show/young-sheldon', 'https://www.justwatch.com/in/tv-show/poacher', 'https://www.justwatch.com/in/tv-show/mastram', 'https://www.justwatch.com/in/tv-show/farzi', 'https://www.justwatch.com/in/tv-show/the-twelve', 'https://www.justwatch.com/in/tv-show/jujutsu-kaisen', 'https://www.justwatch.com/in/tv-show/yellowstone', 'https://www.justwatch.com/in/tv-show/maharani-2021', 'https://www.justwatch.com/in/tv-show/avatar-the-last-airbender-2005', 'https://www.justwatch.com/in/tv-show/jack-reacher', 'https://www.justwatch.com/in/tv-show/maamla-legal-hai', 'https://www.justwatch.com/in/tv-show/criminal-justice-2019', 'https://www.justwatch.com/in/tv-show/bigg-boss', 'https://www.justwatch.com/in/tv-show/scam-1992', 'https://www.justwatch.com/in/tv-show/loki', 'https://www.justwatch.com/in/tv-show/paperhouse', 'https://www.justwatch.com/in/tv-show/aashram', 'https://www.justwatch.com/in/tv-show/the-rookie', 'https://www.justwatch.com/in/tv-show/lucifer', 'https://www.justwatch.com/in/tv-show/euphoria', 'https://www.justwatch.com/in/tv-show/the-family-man', 'https://www.justwatch.com/in/tv-show/mr-and-mrs-smith', 'https://www.justwatch.com/in/tv-show/gandii-baat', 'https://www.justwatch.com/in/tv-show/mashle-magic-and-muscles', 'https://www.justwatch.com/in/tv-show/masters-of-the-air', 'https://www.justwatch.com/in/tv-show/gullak', 'https://www.justwatch.com/in/tv-show/breaking-bad', 'https://www.justwatch.com/in/tv-show/house-of-ninjas', 'https://www.justwatch.com/in/tv-show/the-last-of-us', 'https://www.justwatch.com/in/tv-show/naruto-shippuden', 'https://www.justwatch.com/in/tv-show/a-killer-paradox', 'https://www.justwatch.com/in/tv-show/the-bear', 'https://www.justwatch.com/in/tv-show/the-indrani-mukerjea-story-buried-truth', 'https://www.justwatch.com/in/tv-show/house-of-the-dragon', 'https://www.justwatch.com/in/tv-show/demon-slayer-kimetsu-no-yaiba', 'https://www.justwatch.com/in/tv-show/tokyo-vice', 'https://www.justwatch.com/in/tv-show/spartacus', 'https://www.justwatch.com/in/tv-show/fargo', 'https://www.justwatch.com/in/tv-show/modern-family', 'https://www.justwatch.com/in/tv-show/succession', 'https://www.justwatch.com/in/tv-show/superman-and-lois', 'https://www.justwatch.com/in/tv-show/the-great-indian-murder', 'https://www.justwatch.com/in/tv-show/shark-tank-india', 'https://www.justwatch.com/in/tv-show/naruto', 'https://www.justwatch.com/in/tv-show/dark-desire', 'https://www.justwatch.com/in/tv-show/supersex', 'https://www.justwatch.com/in/tv-show/the-freelancer', 'https://www.justwatch.com/in/tv-show/the-railway-men-the-untold-story-of-bhopal-1984', 'https://www.justwatch.com/in/tv-show/one-piece-2023', 'https://www.justwatch.com/in/tv-show/p-i-meena', 'https://www.justwatch.com/in/tv-show/peaky-blinders', 'https://www.justwatch.com/in/tv-show/scam-2003-the-telgi-story', 'https://www.justwatch.com/in/tv-show/apharan', 'https://www.justwatch.com/in/tv-show/asur', 'https://www.justwatch.com/in/tv-show/mayor-of-kingstown', 'https://www.justwatch.com/in/tv-show/monarch-legacy-of-monsters', 'https://www.justwatch.com/in/tv-show/the-legend-of-hanuman', 'https://www.justwatch.com/in/tv-show/college-romance', 'https://www.justwatch.com/in/tv-show/marry-my-husband', 'https://www.justwatch.com/in/tv-show ...

# %%
# Write Your Code here


# Initializing an empty list to store series titles
list_of_series_titles = [
    (
        BeautifulSoup(requests.get(url).text, 'html.parser').find('h1').text.strip()
        if (soup := BeautifulSoup(requests.get(url).text, 'html.parser').find('h1'))
        else f"Title not found for {url}"
    )
    for url in list_of_series_links
]

# Print the list of extracted series titles
print(list_of_series_titles)
# Out:
# ['Panchayat  (2020)', 'Game of Thrones  (2011)', 'Mirzapur  (2018)', 'Shōgun  (2024)', 'True Detective  (2014)', 'Avatar: The Last Airbender  (2024)', 'One Day  (2024)', 'Aarya  (2020)', 'Solo Leveling  (2024)', 'Sunflower  (2021)', 'Halo  (2022)', 'Indian Police Force  (2024)', 'Death and Other Details  (2024)', 'Young Sheldon  (2017)', 'Poacher  (2023)', 'Mastram  (2020)', 'Farzi  (2023)', 'The Twelve  (2019)', 'Jujutsu Kaisen  (2020)', 'Yellowstone  (2018)', 'Maharani  (2021)', 'Avatar: The Last Airbender  (2005)', 'Reacher  (2022)', 'Maamla Legal Hai  (2024)', 'Criminal Justice  (2019)', 'Bigg Boss  (2006)', 'Scam 1992  (2020)', 'Loki  (2021)', 'Money Heist  (2017)', 'Aashram  (2020)', 'The Rookie  (2018)', 'Lucifer  (2016)', 'Euphoria  (2019)', 'The Family Man  (2019)', 'Mr. & Mrs. Smith  (2024)', 'Gandii Baat  (2018)', 'Mashle: Magic and Muscles  (2023)', 'Masters of the Air  (2024)', 'Gullak  (2019)', 'Breaking Bad  (2008)', 'House of Ninjas  (2024)', 'The Last of Us  (2023)', 'Naruto Shippūden  (2007)', 'A Killer Paradox  (2024)', 'The Bear  (2022)', 'The Indrani Mukerjea Story: Buried Truth  (2024)', 'House of the Dragon  (2022)', 'Demon Slayer: Kimetsu no Yaiba  (2019)', 'Tokyo Vice  (2022)', 'Spartacus  (2010)', 'Fargo  (2014)', 'Modern Family  (2009)', 'Succession  (2018)', 'Superman & Lois  (2021)', 'The Great Indian Murder  (2022)', 'Shark Tank India  (2021)', 'Naruto  (2002)', 'Dark Desire  (2020)', 'Supersex  (2024)', 'The Freelancer  (2023)', 'The Railway Men - The Untold Story of Bhopal 1984  (2023)', 'ONE PIECE  (2023)', 'P.I. Meena  (2023)', 'Peaky Blinders  (2013)', 'Scam 2003: The Telgi Story  (2023)', 'Apharan  (2018)', 'Asur: Welcome to Your Dark Side  (2020)', 'Mayor of Kingstown  (2021)', 'Monarch: Legacy of Monsters  (2023)', 'The Legend of Hanuman  (2021)', 'College Romance  (2018)', 'Marry My Husband  (2024)', 'Good Morning, Verônica  (2020)', 'The Vampire Diaries  (2009)', 'Tadap  (2019)', 'The Gentlemen  (2024)', 'Stranger Things  (2016)', 'The Walking Dead  (2010)', 'Jab Mila Tu  (2024)', 'She  (2020)', 'The Flash  (2014)', 'Flames  (2018)', 'Constellation  (2024)', 'Berlin  (2023)', 'Taaza Khabar  (2023)', 'Shameless  (2011)', 'The Witcher  (2019)', 'The King: Eternal Monarch  (2020)', 'His Dark Materials  (2019)', 'Better Call Saul  (2015)', 'ted  (2024)', 'My Demon  (2023)', 'Kaisi Yeh Yaariyan  (2014)', 'The Boys  (2019)', 'One-Punch Man  (2015)', 'FEUD  (2017)', 'Aspirants  (2021)', 'Arthdal Chronicles  (2019)', "Death's Game  (2023)", 'The Good Doctor  (2017)']

# %% [markdown]
# ## **Fetching Release Year**

# %%
# Write Your Code here
# Initializing an empty list to store release years
list_of_release_years = [
    (
        soup.find('span', class_="text-muted").text.replace('(', '').replace(')', '').strip()
        if (soup := BeautifulSoup(requests.get(url).text, 'html.parser')).find('span', class_="text-muted")
        else f"Release year not found for {url}"
    )
    for url in list_of_series_links
]

# Print the list of extracted release years without parentheses
print(list_of_release_years)
# Out:
# ['2020', '2011', '2018', '2024', '2014', '2024', '2024', '2020', '2024', '2021', '2022', '2024', '2024', '2017', '2023', '2020', '2023', '2019', '2020', '2018', '2021', '2005', '2022', '2024', '2019', '2006', '2020', '2021', '2017', '2020', '2018', '2016', '2019', '2019', '2024', '2018', '2023', '2024', '2019', '2008', '2024', '2023', '2007', '2024', '2022', '2024', '2022', '2019', '2022', '2010', '2014', '2009', '2018', '2021', '2022', '2021', '2002', '2020', '2024', '2023', '2023', '2023', '2023', '2013', '2023', '2018', '2020', '2021', '2023', '2021', '2018', '2024', '2020', '2009', '2019', '2024', '2016', '2010', '2024', '2020', '2014', '2018', '2024', '2023', '2023', '2011', '2019', '2020', '2019', '2015', '2024', '2023', '2014', '2019', '2015', '2017', '2021', '2019', '2023', '2017']

# %% [markdown]
# ## **Fetching TV Show Genre Details**

# %%
# Write Your Code here
# Initializing an empty list to store genres
list_of_genres_series = []

# Iterating through each series link in the list (list_of_series_links)
for series_link in list_of_series_links:
    # Set the current URL
    url_for_series = series_link

    try:
        # Sending an HTTP GET request to the series URL
        page_for_series = requests.get(url_for_series)
        page_for_series.raise_for_status()  # Raise an exception for bad responses (e.g., 404)

        # Parsing the HTML content using BeautifulSoup with the 'html.parser'
        soup_for_series = BeautifulSoup(page_for_series.text, 'html.parser')

        # Find the <h3> tag containing "Genres"
        genres_heading = soup_for_series.find('h3', class_="detail-infos__subheading", string="Genres")

        # Check if the <h3> tag is found
        if genres_heading:
            # Extract the next sibling <div> tag (which contains the genres)
            genres_div = genres_heading.find_next('div', class_="detail-infos__value")
            if genres_div:
                # Extract the text content of the <div> tag and strip extra whitespaces
                genres_text = genres_div.text.strip()
                list_of_genres_series.append(genres_text)
            else:
                list_of_genres_series.append(f"Genres not found for {url_for_series}")
        else:
            list_of_genres_series.append(f"Genres heading not found for {url_for_series}")

    except requests.exceptions.RequestException as req_ex:
        # Handle potential HTTP request errors
        print(f"Error fetching {url_for_series}: {req_ex}")
        list_of_genres_series.append(f"Error fetching {url_for_series}")

    except Exception as ex:
        # Handle other unexpected exceptions
        print(f"Error processing {url_for_series}: {ex}")
        list_of_genres_series.append(f"Error processing {url_for_series}")

# Printing the list of extracted genres
print(list_of_genres_series)
# Out:
# ['Comedy, Drama', 'Drama, Action & Adventure, Science-Fiction, Fantasy', 'Crime, Action & Adventure, Drama, Mystery & Thriller', 'Drama, History, War & Military', 'Drama, Mystery & Thriller, Crime', 'Science-Fiction, Action & Adventure, Comedy, Drama, Kids & Family, Fantasy', 'Comedy, Drama, Romance', 'Crime, Drama, Mystery & Thriller, Action & Adventure', 'Animation, Action & Adventure, Fantasy, Science-Fiction', 'Comedy, Crime', 'Action & Adventure, Science-Fiction, Mystery & Thriller, War & Military', 'Action & Adventure, Crime', 'Mystery & Thriller, Drama, Crime', 'Comedy, Kids & Family', 'Crime, Drama', 'Drama, Comedy, Fantasy', 'Crime, Drama, Mystery & Thriller', 'Drama, Mystery & Thriller', 'Animation, Action & Adventure, Fantasy, Mystery & Thriller, Science-Fiction', 'Drama, Western', 'Drama', 'Action & Adventure, Science-Fiction, Kids & Family, Fantasy, Animation', 'Drama, Mystery & Thriller, Action & Adventure, Crime', 'Drama', 'Drama, Crime, Mystery & Thriller', 'Reality TV, Kids & Family', 'Crime, Drama, Mystery & Thriller', 'Action & Adventure, Fantasy, Science-Fiction, Drama', 'Mystery & Thriller, Action & Adventure, Crime, Drama, Made in Europe', 'Crime, Drama, Mystery & Thriller', 'Drama, Comedy, Action & Adventure, Crime', 'Crime, Science-Fiction, Fantasy, Drama', 'Drama', 'Action & Adventure, Comedy, Drama', 'Drama, Comedy, Action & Adventure, Crime, Mystery & Thriller', 'Crime, Drama, Mystery & Thriller', 'Animation, Action & Adventure, Comedy, Fantasy, Science-Fiction', 'Drama, War & Military, Mystery & Thriller, Action & Adventure', 'Drama, Kids & Family, Comedy', 'Drama, Crime, Mystery & Thriller', 'Action & Adventure, Drama, Mystery & Thriller', 'Drama, Action & Adventure, Horror, Science-Fiction, Mystery & Thriller', 'Action & Adventure, Science-Fiction, Animation, Comedy, Drama, Fantasy', 'Comedy, Crime, Mystery & Thriller', 'Drama, Comedy', 'Documentary, Crime', 'Science-Fiction, Drama, Action & Adventure, Fantasy, Romance', 'Animation, Action & Adventure, Fantasy, Mystery & Thriller, Science-Fiction', 'Crime, Drama, Mystery & Thriller', 'Drama, Romance, Action & Adventure', 'Drama, Mystery & Thriller, Crime', 'Drama, Romance, Comedy', 'Drama, Comedy', 'Science-Fiction, Drama, Romance, Action & Adventure', 'Crime, Mystery & Thriller', 'Reality TV', 'Action & Adventure, Science-Fiction, Animation, Comedy, Fantasy', 'Mystery & Thriller, Drama', 'Drama, History', 'Mystery & Thriller, Action & Adventure, Drama', 'Drama, History, Mystery & Thriller', 'Action & Adventure, Science-Fiction, Comedy, Drama, Fantasy', 'Mystery & Thriller, Crime', 'Drama, Crime', 'Drama', 'Drama, Mystery & Thriller, Action & Adventure, Crime', 'Mystery & Thriller, Crime, Drama', 'Drama, Crime, Mystery & Thriller', 'Drama, Science-Fiction, Action & Adventure', 'Animation, Action & Adventure, Fantasy', 'Comedy, Drama, Romance', 'Fantasy, Romance, Comedy, Drama, Science-Fiction', 'Crime, Drama, Mystery & Thriller', 'Science-Fiction, Horror, Romance, Mystery & Thriller, Drama, Fantasy', 'Drama, Romance', 'Comedy, Crime, Action & Adventure', 'Drama, Science-Fiction, Mystery & Thriller, Fantasy, Horror', 'Action & Adventure, Drama, Science-Fiction, Horror, Mystery & Thriller', 'Romance, Drama', 'Drama, Crime', 'Drama, Science-Fiction, Action & Adventure', 'Comedy, Drama, Romance, Made in Europe', 'Mystery & Thriller, Drama, Science-Fiction', 'Crime, Drama, Action & Adventure, Mystery & Thriller', 'Science-Fiction, Drama, Action & Adventure, Comedy, Fantasy, Mystery & Thriller', 'Drama, Comedy', 'Action & Adventure, Science-Fiction, Drama, Fantasy', 'Science-Fiction, Drama', 'Science-Fiction, Drama, Fantasy', 'Crime, Drama', 'Comedy', 'Science-Fiction, Fantasy, Romance, Comedy, Drama', 'Drama', 'Science-Fiction, Action & Adventure, Comedy, Crime, Drama', 'Action & Adventure, Animation, Comedy, Kids & Family, Fantasy, Science-Fiction', 'Drama', 'Drama', 'Drama, Action & Adventure, Fantasy, History, Romance', 'Drama, Science-Fiction, Fant ...

# %% [markdown]
# ## **Fetching IMDB Rating Details**

# %%
# Write Your Code here

# Initializing an empty list to store IMDb ratings
list_of_imdb_ratings = [
    (
        re.search(r'\d+\.\d+', imdb_img.find_next('span').get_text()).group()
        if (imdb_img := soup.find('img', alt=re.compile(r'IMDB'))) else
        "IMDb Rating not found"
    )
    for series_link in list_of_series_links
    if (page_for_series := requests.get(series_link)).ok and
       (soup := BeautifulSoup(page_for_series.text, 'html.parser'))
]

# Printing the list of extracted IMDb ratings
print(list_of_imdb_ratings)
# Out:
# ['8.9', '9.2', '8.5', '9.2', '8.9', '7.3', '8.2', '7.9', '8.5', '7.5', '7.2', '5.1', '6.8', '7.6', '7.7', '7.1', '8.4', '7.4', '8.6', '8.7', '7.9', '9.3', '8.1', 'IMDb Rating not found', '8.1', '3.7', '9.3', '8.2', '8.2', '7.4', '8.0', '8.1', '8.3', '8.7', '7.0', '3.4', '7.6', '7.9', '9.1', '9.5', '7.3', '8.7', '8.7', '7.2', '8.6', '6.3', '8.4', '8.7', '8.0', '8.5', '8.9', '8.5', '8.8', '7.8', '6.8', '8.7', '8.4', '6.5', '6.0', '8.1', '8.5', '8.3', '6.1', '8.8', 'IMDb Rating not found', '8.3', '8.5', '8.2', '7.0', '9.1', '8.3', '7.9', '7.5', '7.7', '5.8', '8.4', '8.7', '8.1', '7.8', '6.4', '7.5', '8.9', '7.0', '7.0', '8.1', '8.5', '8.0', 'IMDb Rating not found', '7.8', '9.0', '8.0', '7.7', '8.0', '8.7', '8.7', '8.4', '9.2', '8.3', '8.6', '8.0']

# %% [markdown]
# ## **Fetching Age Rating Details**

# %%
# Write Your Code here
# Initializing an empty list to store age ratings
list_of_age_ratings = []

# Iterate through each series link in the list (list_of_series_links)
for series_link in list_of_series_links:
    try:
        # Sending an HTTP GET request to the series URL
        page_for_series = requests.get(series_link)
        page_for_series.raise_for_status()  # Raise an exception for bad responses (e.g., 404)

        # Parsing the HTML content using BeautifulSoup with the 'html.parser'
        soup_for_series = BeautifulSoup(page_for_series.text, 'html.parser')

        # Find the h3 tag with class 'detail-infos__subheading' and text 'Age rating'
        age_rating_heading = soup_for_series.find('h3', class_='detail-infos__subheading', string='Age rating')

        if age_rating_heading:
            # Extract age rating from the following sibling div
            age_rating = age_rating_heading.find_next('div', class_='detail-infos__value').get_text(strip=True)
            list_of_age_ratings.append(age_rating)
        else:
            list_of_age_ratings.append("Age rating not found")

    except requests.exceptions.RequestException as req_ex:
        # Handle potential HTTP request errors
        print(f"Error fetching {series_link}: {req_ex}")
        list_of_age_ratings.append(f"Error fetching {series_link}")

    except Exception as ex:
        # Handle other unexpected exceptions
        print(f"Error processing {series_link}: {ex}")
        list_of_age_ratings.append(f"Error processing {series_link}")

# Print the list of extracted age ratings
print(list_of_age_ratings)
# Out:
# ['Age rating not found', 'U', 'Age rating not found', 'Age rating not found', 'U', 'Age rating not found', 'A', 'Age rating not found', 'Age rating not found', 'A', 'Age rating not found', 'A', 'Age rating not found', 'U', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'UA', 'U', 'A', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'U', 'A', 'Age rating not found', 'Age rating not found', 'A', 'Age rating not found', 'A', 'Age rating not found', 'U', 'Age rating not found', 'A', 'U', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'A', 'Age rating not found', 'A', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'U', 'Age rating not found', 'Age rating not found', 'U', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'A', 'A', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'A', 'Age rating not found', 'Age rating not found', 'U', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'U', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'A', 'Age rating not found', 'Age rating not found', 'U', 'A', 'Age rating not found', 'Age rating not found', 'A', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'A', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'Age rating not found', 'U']

# %% [markdown]
# ## **Fetching Production Country details**

# %%
# Write Your Code here

# Initializing an empty list to store production countries
list_of_production_countries = []

for series_link in list_of_series_links:
    try:
        # Sending an HTTP GET request to the series URL
        page_for_series = requests.get(series_link, timeout=10)  # Adjust timeout as needed
        page_for_series.raise_for_status()

        # Parsing the HTML content using BeautifulSoup with the 'html.parser'
        soup_for_series = BeautifulSoup(page_for_series.text, 'html.parser')

        # Find the production country directly
        production_country = soup_for_series.find('h3', class_='detail-infos__subheading', string=re.compile(r'production\s*country', re.I))

        if production_country:
            production_country = production_country.find_next('div', class_='detail-infos__value').get_text(strip=True)
            list_of_production_countries.append(production_country)
        else:
            list_of_production_countries.append("Production country not found")

    except requests.exceptions.RequestException as req_ex:
        # Handle potential HTTP request errors
        print(f"Error fetching {series_link}: {req_ex}")
        list_of_production_countries.append(f"Error fetching {series_link}")

    except Exception as ex:
        # Handle other unexpected exceptions
        print(f"Error processing {series_link}: {ex}")
        list_of_production_countries.append(f"Error processing {series_link}")

# Print the list of extracted production countries
print(list_of_production_countries)
# Out:
# ['India', 'United States', 'India', 'United States', 'United States', 'United States', 'United Kingdom', 'India', 'Japan, South Korea', 'India', 'United States', 'India', 'United States', 'United States', 'United States, India', 'India', 'India', 'Belgium', 'Japan, United States', 'United States', 'India', 'United States', 'United States', 'India', 'India', 'India', 'India', 'United States', 'Spain', 'India', 'United States', 'United States', 'United States', 'India', 'United States', 'India', 'Japan', 'United States', 'India', 'United States', 'Japan', 'United States', 'Japan', 'South Korea', 'United States', 'India', 'United States', 'Japan', 'United States', 'United States', 'United States', 'United States', 'United States', 'United States', 'India', 'India', 'Japan', 'Mexico', 'Italy', 'India', 'India', 'United States', 'India', 'United Kingdom', 'India', 'India', 'India', 'United States', 'United States', 'India', 'India', 'South Korea', 'Brazil', 'United States', 'India', 'United Kingdom, United States', 'United States', 'United States', 'India', 'India', 'United States', 'India', 'France, Germany, United Kingdom', 'Spain', 'India', 'United States', 'United States', 'South Korea', 'United Kingdom', 'United States', 'United States', 'South Korea', 'India', 'United States', 'Japan', 'United States', 'India', 'South Korea', 'South Korea', 'United States']

# %% [markdown]
# ## **Fetching Streaming Service details**

# %%
# Write Your Code here

# Initializing an empty list to store streaming services
list_of_streaming_services = [
    (
        streaming_service_icon['alt']
        if (streaming_service_icon := soup_for_series.find('img', class_='offer__icon')) else
        "Streaming services not found"
    )
    for series_link in list_of_series_links
    if (page_for_series := requests.get(series_link)).ok and
       (soup_for_series := BeautifulSoup(page_for_series.text, 'html.parser'))
]

# Printing the list of extracted streaming service information
print(list_of_streaming_services)
# Out:
# ['Amazon Prime Video', 'Jio Cinema', 'Amazon Prime Video', 'Hotstar', 'Jio Cinema', 'Netflix', 'Netflix', 'Hotstar', 'Crunchyroll', 'VI movies and tv', 'Jio Cinema', 'Amazon Prime Video', 'Hotstar', 'Amazon Prime Video', 'Amazon Prime Video', 'Streaming services not found', 'Amazon Prime Video', 'Netflix', 'Crunchyroll', 'Netflix', 'Sony Liv', 'Streaming services not found', 'Amazon Prime Video', 'Netflix', 'Hotstar', 'Streaming services not found', 'Sony Liv', 'Hotstar', 'Netflix', 'MX Player', 'Streaming services not found', 'Netflix', 'Jio Cinema', 'Amazon Prime Video', 'Amazon Prime Video', 'Alt Balaji', 'Crunchyroll', 'Apple TV Plus', 'Sony Liv', 'Netflix', 'Netflix', 'Jio Cinema', 'Crunchyroll', 'Netflix', 'Hotstar', 'Netflix', 'Jio Cinema', 'Crunchyroll', 'Lionsgate Play', 'Lionsgate Play', 'Streaming services not found', 'Hotstar', 'Jio Cinema', 'Amazon Prime Video', 'Hotstar', 'Sony Liv', 'Netflix', 'Netflix', 'Netflix', 'Hotstar', 'Netflix', 'Netflix', 'Amazon Prime Video', 'Netflix', 'Sony Liv', 'Jio Cinema', 'Jio Cinema', 'Amazon Prime Video', 'Apple TV Plus', 'Hotstar', 'Sony Liv', 'Amazon Prime Video', 'Netflix', 'Netflix', 'Jio Cinema', 'Netflix', 'Netflix', 'Netflix', 'Jio Cinema', 'Netflix', 'Streaming services not found', 'Amazon Prime Video', 'Apple TV Plus', 'Netflix', 'Hotstar', 'Netflix', 'Netflix', 'Netflix', 'Jio Cinema', 'Netflix', 'Streaming services not found', 'Netflix', 'Jio Cinema', 'Amazon Prime Video', 'Crunchyroll', 'Hotstar', 'Amazon Prime Video', 'Netflix', 'Amazon Prime Video', 'Netflix']

# %% [markdown]
# ## **Fetching Duration Details**

# %%
# Write Your Code here
# Initialize an empty list to store runtimes
list_of_runtimes = [
    (
        runtime_div.get_text(strip=True)
        if (runtime_div := (soup_for_series.find('h3', class_='detail-infos__subheading', string='Runtime') or {}).find_next('div', class_='detail-infos__value'))
        else "Runtime not found"
    )
    for series_link in list_of_series_links
    if (page_for_series := requests.get(series_link)).ok and
       (soup_for_series := BeautifulSoup(page_for_series.text, 'html.parser'))
]

# Print the list of extracted runtimes
print(list_of_runtimes)
# Out:
# ['33min', '58min', '50min', '57min', '1h 1min', '54min', '29min', '46min', '24min', '37min', '52min', '38min', '45min', '19min', '47min', '28min', '56min', '54min', '23min', '50min', '44min', '24min', '48min', '38min', '50min', '1h 15min', '52min', '49min', '50min', '43min', '43min', '47min', '58min', '45min', '49min', '44min', '23min', '53min', '29min', '47min', '53min', '58min', '24min', '53min', '34min', '46min', '1h 2min', '26min', '58min', '54min', '52min', '21min', '1h 4min', '42min', '45min', '56min', '23min', '34min', '51min', '50min', '59min', '56min', '39min', '58min', '44min', '24min', '47min', '47min', '46min', '21min', '31min', '1h 3min', '49min', '42min', '29min', '50min', '1h 1min', '46min', '25min', '41min', '42min', '31min', '52min', '48min', '29min', '55min', '57min', '1h 12min', '54min', '50min', '36min', '1h 6min', '21min', '1h 1min', '24min', '52min', '44min', '1h 19min', '52min', '43min']

# %% [markdown]
# ## **Creating TV Show DataFrame**

# %%
# Write Your Code here
import pandas as pd

# Creating a table to store series data
dict_for_series_data_frame = {
    "Tv shows Url": list_of_series_links,
    "Tv Show Title": list_of_series_titles,
    "Release Year": list_of_release_years,
    "TV Show Genres": list_of_genres_series,
    "IMDB Rating": list_of_imdb_ratings,
    "Age Rating": list_of_age_ratings,
    "Production Countries": list_of_production_countries,
    "Streaming Service": list_of_streaming_services,
    "Runtime": list_of_runtimes,
}

# Creating a DataFrame from the table
tvshow_dataframe = pd.DataFrame(dict_for_series_data_frame)

# Displaying the DataFrame
tvshow_dataframe
# Out:
#                                          Tv shows Url  \
# 0      https://www.justwatch.com/in/tv-show/panchayat
# 1   https://www.justwatch.com/in/tv-show/game-of-t...
# 2       https://www.justwatch.com/in/tv-show/mirzapur
# 3    https://www.justwatch.com/in/tv-show/shogun-2024
# 4   https://www.justwatch.com/in/tv-show/true-dete...
# ..                                                ...
# 95          https://www.justwatch.com/in/tv-show/feud
# 96     https://www.justwatch.com/in/tv-show/aspirants
# 97  https://www.justwatch.com/in/tv-show/arthdal-c...
# 98   https://www.justwatch.com/in/tv-show/deaths-game
# 99  https://www.justwatch.com/in/tv-show/the-good-...
#
#                  Tv Show Title Release Year  \
# 0            Panchayat  (2020)         2020
# 1      Game of Thrones  (2011)         2011
# 2             Mirzapur  (2018)         2018
# 3               Shōgun  (2024)         2024
# 4       True Detective  (2014)         2014
# ..                         ...          ...
# 95                FEUD  (2017)         2017
# 96           Aspirants  (2021)         2021
# 97  Arthdal Chronicles  (2019)         2019
# 98        Death's Game  (2023)         2023
# 99     The Good Doctor  (2017)         2017
#
#                                        TV Show Genres IMDB Rating  \
# 0                                       Comedy, Drama         8.9
# 1   Drama, Action & Adventure, Science-Fiction, Fa...         9.2
# 2   Crime, Action & Adventure, Drama, Mystery & Th...         8.5
# 3                      Drama, History, War & Military         9.2
# 4                    Drama, Mystery & Thriller, Crime         8.9
# ..                                                ...         ...
# 95                                              Drama         8.4
# 96                                              Drama         9.2
# 97  Drama, Action & Adventure, Fantasy, History, R...         8.3
# 98                    Drama, Science-Fiction, Fantasy         8.6
# 99                                              Drama         8.0
#
#               Age Rating Production Countries   Streaming Service   Runtime
# 0   Age rating not found                India  Amazon Prime Video     33min
# 1                      U        United States          Jio Cinema     58min
# 2   Age rating not found                India  Amazon Prime Video     50min
# 3   Age rating not found        United States             Hotstar     57min
# 4                      U        United States          Jio Cinema   1h 1min
# ..                   ...                  ...                 ...       ...
# 95  Age rating not found        United States             Hotstar     52min
# 96  Age rating not found                India  Amazon Prime Video     44min
# 97  Age rating not found          South Korea             Netflix  1h 19min
# 98  Age rating not found          South Korea  Amazon Prime Video     52min
# 99                     U        United States             Netflix     43min
#
# [100 rows x 9 columns]

# %% [markdown]
# ## **Task 2 :- Data Filtering & Analysis**

# %%
# Write Your Code here
from datetime import datetime

# Convertimg 'Release Year' and 'Rating' columns to numeric

tvshow_dataframe['Release Year'] = pd.to_numeric(tvshow_dataframe['Release Year'], errors='coerce')
tvshow_dataframe['IMDB Rating'] = pd.to_numeric(tvshow_dataframe['IMDB Rating'], errors='coerce')

# Get the current year
current_year = datetime.now().year

# Filter movies and TV shows released in the last 3 years
recent_tvshow = tvshow_dataframe[tvshow_dataframe['Release Year'] >= current_year - 3]

# Filter movies and TV shows with an IMDb rating of 8 or higher
high_rated_tvshow = tvshow_dataframe[tvshow_dataframe['IMDB Rating'] >= 8.0]

# Save filtered movies and TV shows in new dataframe variables
filtered_tvshow = recent_tvshow[recent_tvshow['IMDB Rating'] >= 8.0]

# Display the filtered dataframe of movi
# Out:
#                                           Movie URL's  \
# 5      https://www.justwatch.com/in/movie/oppenheimer
# 8         https://www.justwatch.com/in/movie/hanu-man
# 27   https://www.justwatch.com/in/movie/dune-part-two
# 37          https://www.justwatch.com/in/movie/nani30
# 40  https://www.justwatch.com/in/movie/laapataa-la...
# 41    https://www.justwatch.com/in/movie/interstellar
# 43         https://www.justwatch.com/in/movie/premalu
# 45  https://www.justwatch.com/in/movie/anweshippin...
# 54   https://www.justwatch.com/in/movie/the-holdovers
# 58     https://www.justwatch.com/in/movie/junior-2023
# 60  https://www.justwatch.com/in/movie/k-g-f-chapt...
# 61           https://www.justwatch.com/in/movie/naadu
# 62   https://www.justwatch.com/in/movie/hacksaw-ridge
# 68        https://www.justwatch.com/in/movie/deadpool
# 90  https://www.justwatch.com/in/movie/blade-runne...
# 98     https://www.justwatch.com/in/movie/section-375
#
#                       Movie Title  Release Year  \
# 5             Oppenheimer  (2023)          2024
# 8                Hanu-Man  (2024)          2024
# 27         Dune: Part Two  (2024)          2021
# 37               Hi Nanna  (2023)          2024
# 40        Laapataa Ladies  (2024)          2024
# 41           Interstellar  (2014)          2023
# 43                Premalu  (2024)          2024
# 45  Anweshippin Kandethum  (2024)          2024
# 54          The Holdovers  (2023)          2022
# 58                 Junior  (2023)          2024
# 60       K.G.F: Chapter 1  (2018)          2023
# 61                  Naadu  (2023)          2023
# 62          Hacksaw Ridge  (2016)          2023
# 68               Deadpool  (2016)          2023
# 90      Blade Runner 2049  (2017)          2024
# 98            Section 375  (2019)          2023
#
#                                                Genres  IMDB Rating  \
# 5                                      Drama, History          8.4
# 8                 Comedy, Fantasy, Action & Adventure          8.4
# 27         Science-Fiction, Drama, Action & Adventure          8.9
# 37                      Kids & Family, Romance, Drama          8.2
# 40                                      Comedy, Drama          8.4
# 41         Action & Adventure, Drama, Science-Fiction          8.7
# 43                                    Romance, Comedy          8.3
# 45                   Crime, Drama, Mystery & Thriller          8.0
# 54                                      Comedy, Drama          8.0
# 58                                 Action & Adventure          8.0
# 60  Mystery & Thriller, Drama, Action & Adventure,...          8.2
# 61                                              Drama          8.5
# 62                     Drama, History, War & Military          8.1
# 68                         Comedy, Action & Adventure          8.0
# 90  Science-Fiction, Drama, Mystery & Thriller, Ac...          8.0
# 98                   Crime, Drama, Mystery & Thriller          8.1
#
#    Runtime/Duration            Age Rating Production Countries  \
# 5           3h 0min  Age rating not found        United States
# 8          2h 39min  Age rating not found   Japan, South Korea
# 27         2h 47min  Age rating not found        United States
# 37         2h 35min                     A        United States
# 40          2h 2min  Age rating not found                Japan
# 41         2h 49min                     A        United States
# 43         2h 36min  Age rating not found          South Korea
# 45         2h 22min  Age rating not found                India
# 54         2h 13min  Age rating not found                India
# 58          2h 2min  Age rating not found                Italy
# 60         2h 36min  Age rating not found                India
# 61          2h 8min  Age rating not found        United States
# 62         2h 19min                     A                India
# 68         1h 48min  Age rating not found        United States
# 90         2h 44min  Age rating not found        United States
# 98          2h 4min  Age rating not found          South Korea
#
#                Streaming Service
# 5                       Apple TV
# 8   Streaming services not found
# 27                    Bookmyshow
# 37                       Netflix
# 40                    Bookmyshow
# 41                      Apple TV
# 43                    Bookmyshow
# 45                       Netflix
# 54                    Bookmyshow
# 58            Amazon Prime Video
# 60                       Hotstar
# 61            Amazon Prime Video
# 62            Amazon Prime Video
# 68                      Apple TV
# 90                      Apple TV
# 98            Amazon Prime Video

# %%
# Display the filtered dataframe of tv shows
filtered_tvshow
# Out:
#                                          Tv shows Url  \
# 3    https://www.justwatch.com/in/tv-show/shogun-2024
# 6        https://www.justwatch.com/in/tv-show/one-day
# 8   https://www.justwatch.com/in/tv-show/solo-leve...
# 16         https://www.justwatch.com/in/tv-show/farzi
# 22  https://www.justwatch.com/in/tv-show/jack-reacher
# 27          https://www.justwatch.com/in/tv-show/loki
# 41  https://www.justwatch.com/in/tv-show/the-last-...
# 44      https://www.justwatch.com/in/tv-show/the-bear
# 46  https://www.justwatch.com/in/tv-show/house-of-...
# 48    https://www.justwatch.com/in/tv-show/tokyo-vice
# 55  https://www.justwatch.com/in/tv-show/shark-tan...
# 59  https://www.justwatch.com/in/tv-show/the-freel...
# 60  https://www.justwatch.com/in/tv-show/the-railw...
# 61  https://www.justwatch.com/in/tv-show/one-piece...
# 67  https://www.justwatch.com/in/tv-show/mayor-of-...
# 69  https://www.justwatch.com/in/tv-show/the-legen...
# 75  https://www.justwatch.com/in/tv-show/the-gentl...
# 84  https://www.justwatch.com/in/tv-show/taaza-khabar
# 90           https://www.justwatch.com/in/tv-show/ted
# 96     https://www.justwatch.com/in/tv-show/aspirants
# 98   https://www.justwatch.com/in/tv-show/deaths-game
#
#                                         Tv Show Title  Release Year  \
# 3                                      Shōgun  (2024)          2024
# 6                                     One Day  (2024)          2024
# 8                               Solo Leveling  (2024)          2024
# 16                                      Farzi  (2023)          2023
# 22                                    Reacher  (2022)          2022
# 27                                       Loki  (2021)          2021
# 41                             The Last of Us  (2023)          2023
# 44                                   The Bear  (2022)          2022
# 46                        House of the Dragon  (2022)          2022
# 48                                 Tokyo Vice  (2022)          2022
# 55                           Shark Tank India  (2021)          2021
# 59                             The Freelancer  (2023)          2023
# 60  The Railway Men - The Untold Story of Bhopal 1...          2023
# 61                                  ONE PIECE  (2023)          2023
# 67                         Mayor of Kingstown  (2021)          2021
# 69                      The Legend of Hanuman  (2021)          2021
# 75                              The Gentlemen  (2024)          2024
# 84                               Taaza Khabar  (2023)          2023
# 90                                        ted  (2024)          2024
# 96                                  Aspirants  (2021)          2021
# 98                               Death's Game  (2023)          2023
#
#                                        TV Show Genres  IMDB Rating  \
# 3                      Drama, History, War & Military          9.2
# 6                              Comedy, Drama, Romance          8.2
# 8   Animation, Action & Adventure, Fantasy, Scienc...          8.5
# 16                   Crime, Drama, Mystery & Thriller          8.4
# 22  Drama, Mystery & Thriller, Action & Adventure,...          8.1
# 27  Action & Adventure, Fantasy, Science-Fiction, ...          8.2
# 41  Drama, Action & Adventure, Horror, Science-Fic...          8.7
# 44                                      Drama, Comedy          8.6
# 46  Science-Fiction, Drama, Action & Adventure, Fa...          8.4
# 48                   Crime, Drama, Mystery & Thriller          8.0
# 55                                         Reality TV          8.7
# 59      Mystery & Thriller, Action & Adventure, Drama          8.1
# 60                 Drama, History, Mystery & Thriller          8.5
# 61  Action & Adventure, Science-Fiction, Comedy, D...          8.3
# 67                   Drama, Crime, Mystery & Thriller          8.2
# 69             Animation, Action & Adventure, Fantasy          9.1
# 75                  Comedy, Crime, Action & Adventure          8.4
# 84  Science-Fiction, Drama, Action & Adventure, Co...          8.1
# 90                                             Comedy          8.0
# 96                                              Drama          9.2
# 98                    Drama, Science-Fiction, Fantasy          8.6
#
#               Age Rating           Production Countries  \
# 3   Age rating not found                  United States
# 6                      A                 United Kingdom
# 8   Age rating not found             Japan, South Korea
# 16  Age rating not found                          India
# 22                     A                  United States
# 27  Age rating not found                  United States
# 41                     A                  United States
# 44  Age rating not found                  United States
# 46                     A                  United States
# 48                     A                  United States
# 55                     U                          India
# 59  Age rating not found                          India
# 60  Age rating not found                          India
# 61  Age rating not found                  United States
# 67  Age rating not found                  United States
# 69  Age rating not found                          India
# 75  Age rating not found  United Kingdom, United States
# 84  Age rating not found                          India
# 90  Age rating not found                  United States
# 96  Age rating not found                          India
# 98  Age rating not found                    South Korea
#
#                Streaming Service  Runtime
# 3                        Hotstar    57min
# 6                        Netflix    29min
# 8                    Crunchyroll    24min
# 16            Amazon Prime Video    56min
# 22            Amazon Prime Video    48min
# 27                       Hotstar    49min
# 41                    Jio Cinema    58min
# 44                       Hotstar    34min
# 46                    Jio Cinema  1h 2min
# 48                Lionsgate Play    58min
# 55                      Sony Liv    56min
# 59                       Hotstar    50min
# 60                       Netflix    59min
# 61                       Netflix    56min
# 67            Amazon Prime Video    47min
# 69                       Hotstar    21min
# 75                       Netflix    50min
# 84                       Hotstar    29min
# 90  Streaming services not found    36min
# 96            Amazon Prime Video    44min
# 98            Amazon Prime Video    52min

# %% [markdown]
# ## **Calculating Mean IMDB Ratings for both Movies and Tv Shows**

# %%
# Write Your Code here
import pandas as pd

# Convert 'IMDB Rating' column to numeric, replacing non-numeric values with NaN
#movies_dataframe['IMDB Rating'] = pd.to_numeric(movies_dataframe['IMDB Rating'], errors='coerce')
tvshow_dataframe['IMDB Rating'] = pd.to_numeric(tvshow_dataframe['IMDB Rating'], errors='coerce')

# Calculate the mean IMDb rating for movies
#mean_imdb_rating_movies = movies_dataframe['IMDB Rating'].mean()

# Calculate the mean IMDb rating for TV shows
mean_imdb_rating_series = tvshow_dataframe['IMDB Rating'].mean()

#print(f"Mean IMDB Rating for Movies: {mean_imdb_rating_movies}")
print(f"Mean IMDB Rating for TV Shows: {mean_imdb_rating_series}")
# Out:
# Mean IMDB Rating for Movies: 7.208080808080808
# Mean IMDB Rating for TV Shows: 7.9402061855670105

# %% [markdown]
# ## **Analyzing Top Genres**

# %%
# Write Your Code here
# Split the genres string into a list for TV series
tvshow_dataframe['TV Show Genres'] = tvshow_dataframe['TV Show Genres'].apply(lambda x: x.split(', ') if pd.notna(x) else x)
genres_list_series = [genre for genres in tvshow_dataframe['TV Show Genres'].dropna() for genre in genres]
genre_counts_series = pd.Series(genres_list_series).value_counts()

# Split the genres string into a list for movies
#movies_dataframe['Genres'] = movies_dataframe['Genres'].str.split(', ')
#genres_list_movies = [genre for genres in movies_dataframe['Genres'].dropna() for genre in genres]
#genre_counts_movies = pd.Series(genres_list_movies).value_counts()

# Identify the top 5 genres for TV series and movies
top_genres_series = genre_counts_series.head(5)
#top_genres_movies = genre_counts_movies.head(5)

print("Top 5 Genres in TV Series:")
print(top_genres_series)

print("\nTop 5 Genres in Movies:")
#print(top_genres_movies)
# Out:
# Top 5 Genres in TV Series:
# Drama                 80
# Action & Adventure    39
# Mystery & Thriller    38
# Crime                 34
# Science-Fiction       31
# dtype: int64
#
# Top 5 Genres in Movies:
# Drama                 72
# Action & Adventure    47
# Mystery & Thriller    40
# Comedy                29
# Crime                 21
# dtype: int64

# %%
#Let's Visvalize it using word cloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def generate_and_plot_wordcloud(data, title):
    # Generating a word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(data)

    # Ploting the word cloud
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title)
    plt.axis('off')

# Ploting the word clouds for TV series and movies
plt.figure(figsize=(16, 8))


plt.subplot(1, 2, 1)
generate_and_plot_wordcloud(top_genres_movies, 'Top Genres in Movies')

plt.subplot(1, 2, 2)
generate_and_plot_wordcloud(top_genres_series, 'Top Genres in TV Shows')

plt.tight_layout()  # Improve spacing between subplots
plt.show()

# %% [markdown]
# ## **Finding Predominant Streaming Service**

# %%
# Write Your Code here
import pandas as pd

def count_and_display_top_services(dataframe, media_type):
    # Counting the occurrences of each streaming service
    top_streaming_services = dataframe['Streaming Service'].value_counts().reset_index()
    top_streaming_services.columns = ['Streaming Service', f'Number of {media_type}']

    # Display the top streaming services
    print(f'Top Streaming Services for {media_type}:')
    print(top_streaming_services.head())
    print('\n')



# For movies
#count_and_display_top_services(movies_dataframe, 'Movies')

# For TV series
count_and_display_top_services(tvshow_dataframe, 'TV Shows')
# Out:
# Top Streaming Services for Movies:
#               Streaming Service  Number of Movies
# 0                      Apple TV                25
# 1            Amazon Prime Video                22
# 2                       Netflix                14
# 3  Streaming services not found                12
# 4                    Bookmyshow                 9
#
#
# Top Streaming Services for TV Shows:
#               Streaming Service  Number of TV Shows
# 0                       Netflix                  31
# 1            Amazon Prime Video                  17
# 2                    Jio Cinema                  13
# 3                       Hotstar                  12
# 4  Streaming services not found                   7

# %%
#Let's Visvalize it using word cloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def generate_and_plot_wordcloud(data, title):
    # Creating a WordCloud object
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(data)

    # Display the generated word cloud using matplotlib
    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title)
    plt.axis('off')
    plt.show()

# Combining the streaming services from movies and TV series dataframes
#all_streaming_services = pd.concat([movies_dataframe['Streaming Service'], tvshow_dataframe['Streaming Service']])

# Generating and plot the word cloud
#generate_and_plot_wordcloud(all_streaming_services.value_counts(), 'Combined Streaming Services')

# %% [markdown]
# ## **Task 3 :- Data Export**

# %%
#Saving final dataframe as Final Data in csv format
#movies_dataframe.to_csv('Final_Data_of_Movies.csv', index=False)
tvshow_dataframe.to_csv('Final_Data_of_TV_Shows.csv', index=False)



from google.colab import files

# Downloading the CSV file for movies
files.download('Final_Data_of_Movies.csv')

# Downloading the CSV file for TV shows
files.download('Final_Data_of_TV_Shows.csv')

# %%
#saving filter data as Filter Data in csv format
#filtered_movies.to_csv('Filter_Data_of_Movies.csv', index=False)
filtered_tvshow.to_csv('Filter_Data_of_TV_Shows.csv', index=False)

# Downloading the CSV file for Filter Data of movies
files.download('Filter_Data_of_Movies.csv')

# Downloading the CSV file for Filter Data of TV shows
files.download('Filter_Data_of_TV_Shows.csv')
